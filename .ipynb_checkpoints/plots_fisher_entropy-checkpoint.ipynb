# %%
from os.path import exists as exists
import pandas as pd  
import numpy as np
from math import sqrt
import math

# %%
RULES = [1,2]
ENLACES = [1,2,4,8,16,32]
EXPERIMENTOS = list(range(1,11))
PATH_PLOT_ENTROPY = "plot_files\\entropy\\entropy.csv"
PATH_DATA = "data_critical_threshold\\degree_distributions\\"

# %%
def save_csv(data_df, path_file):
    print("Save: ", path_file)
    data_df.to_csv(path_file, sep=',',encoding='utf-8')

# %% [markdown]
# # Obtiene datos de distribicion de grado

# %%
#Recibe la distribucion de grado
def shannon_entropy(Pk):
    H = 0
    for p in Pk:
        if(p > 0):
            H = H - p*math.log(p, 2)
    return H

# %%
def get_df_dd():
    data = dict()
    for rule in RULES:
        data[rule] = dict() 
        for experimento in EXPERIMENTOS:
            data[rule][experimento] = dict()
            for enlace in ENLACES:
                p_deg_dist = PATH_DATA + 'r' + str(rule) + "_enlaceD" + str(enlace) + "_experimento" + str(experimento) + "_ciclo30_dist_degree.csv"
                if exists(p_deg_dist):
                    print("Existe: ", p_deg_dist)
                    data[rule][experimento][enlace] = dict()
                    df_data = pd.read_csv(p_deg_dist,sep=";")[['bins','d']]
                    #critical threshold  
                    # bins - grado
                    # d la cantidad de nodos con ese grado
                    #print("Nodos ", str(df_data['d'].sum()))
                    df_data['k_sum'] = df_data['bins'] * df_data['d']
                    df_data['k2'] = df_data['bins'] * df_data['bins']
                    df_data['k2_sum'] = df_data['k2'] * df_data['d']
                    df_data['p'] = df_data['d'] / 2500 
                    #entropy
                    df_data['ln_k'] = np.log2(df_data['bins'])
                    df_data['ln_k_sum'] = df_data['d'] * df_data['ln_k']
                    df_data.replace([np.inf, -np.inf], 0, inplace=True)
                    df_data = df_data.fillna(0)
                    #print(df_data)
                    #critical threshold  
                    # http://networksciencebook.com/chapter/8#robustness - Critical Threshold (8.7)
                    k_prom = df_data['k_sum'].sum() / 2500
                    k2_prom = df_data['k2_sum'].sum() / 2500
                    fc = 1-(1 / ((k2_prom/k_prom)-1))
                    #print(k_prom)
                    #print(k2_prom)
                    #print('fc= ',fc)
                    #entropy shannon
                    ln_k_sum = df_data['ln_k_sum'].sum()
                    h = ln_k_sum/(2500*np.log(2499))
                    #print('h= ',h)
                    #entropy fisher
                    #print("comprueba densidad ", str(df_data['p'].sum()))
                    p = list(df_data['p'])
                    i = len(p) - 1
                    F_sum = [(sqrt(p[x+1])-sqrt(p[x]))**2 for  x in range(i)]
                    print(sum(F_sum))
                    F = sum(F_sum)*4
                    #print('i=',str(i),"=",str(len(F_sum)))
                    #print("p=",p)
                    #print("F_sum=",F_sum)
                    #print("F=", F)
                    data[rule][experimento][enlace]['fc'] = fc
                    data[rule][experimento][enlace]['h'] = h
                    data[rule][experimento][enlace]['s'] = shannon_entropy(p)
                    data[rule][experimento][enlace]['F'] = F
                else:
                    print("No existe: ", p_deg_dist)
    return data

# %% [markdown]
# Plots files para calcular metricas

# %%
df_dd = get_df_dd()
#print(df_dd)
# Out:
# No existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento1_ciclo30_dist_degree.csv
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento1_ciclo30_dist_degree.csv
# 0.44366895017295677
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento1_ciclo30_dist_degree.csv
# 0.3120259341627256
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento1_ciclo30_dist_degree.csv
# 0.13201218892293642
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento1_ciclo30_dist_degree.csv
# 0.12834040170570077
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento1_ciclo30_dist_degree.csv
# 0.12652173644274367
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento2_ciclo30_dist_degree.csv
# 0.4166645601466555
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento2_ciclo30_dist_degree.csv
# 0.45285212221834575
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento2_ciclo30_dist_degree.csv
# 0.3348083249791604
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento2_ciclo30_dist_degree.csv
# 0.14342629180354308
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento2_ciclo30_dist_degree.csv
# 0.12937264470582266
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento2_ciclo30_dist_degree.csv
# 0.12275388402073514
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento3_ciclo30_dist_degree.csv
# 0.47074721634600036
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento3_ciclo30_dist_degree.csv
# 0.45154564018039095
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento3_ciclo30_dist_degree.csv
# 0.32099790747428963
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento3_ciclo30_dist_degree.csv
# 0.13420091744417725
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento3_ciclo30_dist_degree.csv
# 0.12212091192541394
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento3_ciclo30_dist_degree.csv
# 0.11383256836372002
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento4_ciclo30_dist_degree.csv
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0.4316968566983679
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento4_ciclo30_dist_degree.csv
# 0.4614902300924335
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento4_ciclo30_dist_degree.csv
# 0.3080741958964661
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento4_ciclo30_dist_degree.csv
# 0.13655213679569053
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento4_ciclo30_dist_degree.csv
# 0.1298420785530752
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento4_ciclo30_dist_degree.csv
# 0.11729829541110436
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento5_ciclo30_dist_degree.csv
# 0.46681420976183174
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento5_ciclo30_dist_degree.csv
# 0.42852491162590206
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento5_ciclo30_dist_degree.csv
# 0.3154197331821911
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento5_ciclo30_dist_degree.csv
# 0.13716109775711807
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento5_ciclo30_dist_degree.csv
# 0.12874921285180085
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento5_ciclo30_dist_degree.csv
# 0.12067002258248567
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento6_ciclo30_dist_degree.csv
# 0.44668663725838875
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento6_ciclo30_dist_degree.csv
# 0.43090861446447937
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento6_ciclo30_dist_degree.csv
# 0.32180492006058387
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento6_ciclo30_dist_degree.csv
# 0.13470196678240282
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento6_ciclo30_dist_degree.csv
# 0.1296291101577467
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento6_ciclo30_dist_degree.csv
# 0.12390004051687653
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento7_ciclo30_dist_degree.csv
# 0.44141151579309607
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento7_ciclo30_dist_degree.csv
# 0.43753275546772624
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento7_ciclo30_dist_degree.csv
# 0.30806223515354186
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento7_ciclo30_dist_degree.csv
# 0.13757150446245994
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento7_ciclo30_dist_degree.csv
# 0.13268185149207032
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento7_ciclo30_dist_degree.csv
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0.10550382953139112
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento8_ciclo30_dist_degree.csv
# 0.41944920593710594
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento8_ciclo30_dist_degree.csv
# 0.4636235725426874
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento8_ciclo30_dist_degree.csv
# 0.3171449258306513
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento8_ciclo30_dist_degree.csv
# 0.1322764320336224
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento8_ciclo30_dist_degree.csv
# 0.13266727831921266
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento8_ciclo30_dist_degree.csv
# 0.11815047837144252
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento9_ciclo30_dist_degree.csv
# 0.44528074724819383
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento9_ciclo30_dist_degree.csv
# 0.4209535808350112
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento9_ciclo30_dist_degree.csv
# 0.3172906305698314
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento9_ciclo30_dist_degree.csv
# 0.13574905912394397
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento9_ciclo30_dist_degree.csv
# 0.12693212385868216
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento9_ciclo30_dist_degree.csv
# 0.11920716051407808
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD1_experimento10_ciclo30_dist_degree.csv
# 0.44605889557650513
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD2_experimento10_ciclo30_dist_degree.csv
# 0.4720648503571777
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD4_experimento10_ciclo30_dist_degree.csv
# 0.31549154513468264
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD8_experimento10_ciclo30_dist_degree.csv
# 0.14226528835120925
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD16_experimento10_ciclo30_dist_degree.csv
# 0.13572488438774746
# Existe:  data_critical_threshold\degree_distributions\r1_enlaceD32_experimento10_ciclo30_dist_degree.csv
# 0.12046722588598212
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento1_ciclo30_dist_degree.csv
# 0.1397083195836095
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento1_ciclo30_dist_degree.csv
# 0.16014697088373175
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento1_ciclo30_dist_degree.csv
# 0.20091474349172034
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento1_ciclo30_dist_degree.csv
# 0.16018701454358428
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento1_ciclo30_dist_degree.csv
# 0.11753120685697388
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento1_ciclo30_dist_degree.csv
# 0.24362130448271338
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento2_ciclo30_dist_degree.csv
# 0.13268751273591617
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento2_ciclo30_dist_degree.csv
# 0.16014697088373175
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento2_ciclo30_dist_degree.csv
# 0.19960113572534144
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento2_ciclo30_dist_degree.csv
# 0.15054285515858037
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento2_ciclo30_dist_degree.csv
# 0.12081624425905972
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento2_ciclo30_dist_degree.csv
# 0.2417710040645863
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento3_ciclo30_dist_degree.csv
# 0.14530377641031433
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento3_ciclo30_dist_degree.csv
# 0.13242988071565412
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento3_ciclo30_dist_degree.csv
# 0.1967211706028434
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento3_ciclo30_dist_degree.csv
# 0.15665241176678146
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento3_ciclo30_dist_degree.csv
# 0.11544420846345117
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento3_ciclo30_dist_degree.csv
# 0.23885989827828363
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento4_ciclo30_dist_degree.csv
# 0.1394213698731661
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento4_ciclo30_dist_degree.csv
# 0.12592711287922817
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento4_ciclo30_dist_degree.csv
# 0.2011565869033534
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento4_ciclo30_dist_degree.csv
# 0.16219941360532955
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento4_ciclo30_dist_degree.csv
# 0.11106470296997979
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento4_ciclo30_dist_degree.csv
# 0.2514984032143945
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento5_ciclo30_dist_degree.csv
# 0.13805278695391976
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento5_ciclo30_dist_degree.csv
# 0.13335336394448183
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento5_ciclo30_dist_degree.csv
# 0.18031042081726628
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento5_ciclo30_dist_degree.csv
# 0.16079840412883892
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento5_ciclo30_dist_degree.csv
# 0.11616440140744451
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento5_ciclo30_dist_degree.csv
# 0.24605552912599463
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento6_ciclo30_dist_degree.csv
# 0.14360762608191807
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento6_ciclo30_dist_degree.csv
# 0.17300919584060961
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento6_ciclo30_dist_degree.csv
# 0.20798732574617101
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento6_ciclo30_dist_degree.csv
# 0.1620398967927914
# No existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento6_ciclo30_dist_degree.csv
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento6_ciclo30_dist_degree.csv
# 0.24752519092367783
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento7_ciclo30_dist_degree.csv
# 0.12858420229020975
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento7_ciclo30_dist_degree.csv
# 0.15700081953777803
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento7_ciclo30_dist_degree.csv
# 0.19526209629982794
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento7_ciclo30_dist_degree.csv
# 0.16127269045633913
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento7_ciclo30_dist_degree.csv
# 0.11714034760359751
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento7_ciclo30_dist_degree.csv
# 0.25344510583943447
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento8_ciclo30_dist_degree.csv
# 0.14355102331530387
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento8_ciclo30_dist_degree.csv
# 0.1409434751000611
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento8_ciclo30_dist_degree.csv
# 0.18838052537412792
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento8_ciclo30_dist_degree.csv
# 0.1581809930128664
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento8_ciclo30_dist_degree.csv
# 0.11780837999825047
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento8_ciclo30_dist_degree.csv
# 0.25294946890562664
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento9_ciclo30_dist_degree.csv
# 0.1403428257075935
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento9_ciclo30_dist_degree.csv
# 0.14057291006195724
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento9_ciclo30_dist_degree.csv
# 0.20488673557957
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento9_ciclo30_dist_degree.csv
# 0.16519161381127062
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento9_ciclo30_dist_degree.csv
# 0.11332343584507257
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento9_ciclo30_dist_degree.csv
# 0.23462850692402368
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD1_experimento10_ciclo30_dist_degree.csv
# 0.132711692070372
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD2_experimento10_ciclo30_dist_degree.csv
# 0.14002638223199823
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD4_experimento10_ciclo30_dist_degree.csv
# 0.1909037196478872
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD8_experimento10_ciclo30_dist_degree.csv
# 0.16196623760724044
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD16_experimento10_ciclo30_dist_degree.csv
# 0.11692084419840558
# Existe:  data_critical_threshold\degree_distributions\r2_enlaceD32_experimento10_ciclo30_dist_degree.csv
# 0.24856026395764153
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\snake\anaconda3\envs\netmetrics\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
print(df_dd[1][1][2])
# Out:
# {'fc': 0.8977737392094502, 'h': 0.3650895876907394, 's': 2.652127653769154, 'F': 1.774675800691827}

# %%
results=dict()
if not exists(PATH_PLOT_ENTROPY):
    for r in RULES:
            #print(p_results)
            df_list = list()
            for e in EXPERIMENTOS:
                if e in df_dd[r].keys():
                    df = df_dd[r][e]
                    df_data = pd.DataFrame.from_dict(df).T
                    df_data['experimento'] = e
                    if not df_data.empty:
                        df_list.append(df_data)
            df_entropy = pd.concat(df_list)
            df_entropy.reset_index(inplace=True)
            df_entropy = df_entropy.rename(columns = {'index':'l_max'})
            #print(df_entropy)
            results['F_mean_r'+str(r)] = df_entropy.groupby('l_max')['F'].mean()
            results['F_std_r'+str(r)] = df_entropy.groupby('l_max')['F'].std()
            results['H_mean_r'+str(r)] = df_entropy.groupby('l_max')['h'].mean()
            results['H_std_r'+str(r)] = df_entropy.groupby('l_max')['h'].std()
            results['S_mean_r'+str(r)] = df_entropy.groupby('l_max')['s'].mean()
            results['S_std_r'+str(r)] = df_entropy.groupby('l_max')['s'].std()
            results['CT_mean_r'+str(r)] = df_entropy.groupby('l_max')['fc'].mean()
            results['CT_std_r'+str(r)] = df_entropy.groupby('l_max')['fc'].std()
    pd_results = pd.DataFrame(results)
    pd_results.index.name = 'l_max'
    pd_results = pd_results.sort_values(by=['l_max'],ascending=False)
    print(pd_results)
    #save_csv(pd_results, PATH_PLOT_ENTROPY)
else:
    print('Ya existe ', PATH_PLOT_ENTROPY)
# Out:
#        F_mean_r1  F_std_r1  H_mean_r1  H_std_r1  S_mean_r1  S_std_r1  \
# l_max
# 32      0.475322  0.023545   0.350639  0.000504   1.960630  0.012771
# 16      0.518424  0.014721   0.378055  0.000069   2.631767  0.011790
# 8       0.546367  0.015189   0.375331  0.000077   2.947540  0.005388
# 4       1.268448  0.031134   0.369220  0.000099   2.858631  0.008281
# 2       1.785266  0.067253   0.365189  0.000262   2.652863  0.021303
# 1       1.771027  0.074069   0.365326  0.000315   2.657491  0.023983
#
#        CT_mean_r1  CT_std_r1  F_mean_r2  F_std_r2  H_mean_r2  H_std_r2  \
# l_max
# 32       0.831443   0.000456   0.983566  0.024821   0.351430  0.000476
# 16       0.861380   0.000106   0.464984  0.011160   0.377093  0.000072
# 8        0.867103   0.000161   0.639613  0.016109   0.374596  0.000095
# 4        0.883382   0.000483   0.786450  0.033036   0.372660  0.000173
# 2        0.897868   0.001198   0.585423  0.060915   0.375257  0.001029
# 1        0.896541   0.001252   0.553588  0.021881   0.376039  0.000127
#
#        S_mean_r2  S_std_r2  CT_mean_r2  CT_std_r2
# l_max
# 32      2.036231  0.017895    0.831945   0.000360
# 16      2.793923  0.007780    0.863493   0.000181
# 8       2.948522  0.005676    0.868980   0.000271
# 4       2.949785  0.011819    0.874767   0.000578
# 2       2.896952  0.039218    0.868010   0.002642
# 1       2.865063  0.010579    0.866052   0.000352

# %%
import matplotlib.pyplot as plt
import networkx as nx

def degree_distribution(G):
    vk = dict(G.degree())
    vk = list(vk.values()) # we get only the degree values
    maxk = np.max(vk)
    mink = np.min(min)
    kvalues= np.arange(0,maxk+1) # possible values of k
    Pk = np.zeros(maxk+1) # P(k)
    for k in vk:
        Pk[k] = Pk[k] + 1
    Pk = Pk/sum(Pk) # the sum of the elements of P(k) must to be equal to one
    
    return kvalues,Pk

def shannon_entropy(G):
    k,Pk = degree_distribution(G)
    H = 0
    print(Pk)
    for p in Pk:
        if(p > 0):
            H = H - p*math.log(p, 2)
    return H

G = nx.house_x_graph()
nx.draw_networkx(G)
H = shannon_entropy(G)
print(H)
# Out:
# [0.  0.  0.2 0.4 0.4]
# 1.5219280948873621
